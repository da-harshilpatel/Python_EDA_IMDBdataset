# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.read_csv('Movie+Assignment+Data-Movie+Assignment+Data.csv')
movies = pd.DataFrame(movies)
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
print ('data frame has ', len(movies) , ' rows')
print ('data frame has ', len(movies.columns), ' columns')
print ('data frame shape is ', movies.shape)
print ('data frame has ', movies.size, ' elements')
print ('data frame column names and its datatypes \n',  movies.dtypes)
# Out:
# data frame has  5043  rows
# data frame has  28  columns
# data frame shape is  (5043, 28)
# data frame has  141204  elements
# data frame column names and its datatypes
#  color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# ...

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Number of null values in each column
movies.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# row-wise null count
for i in range(len(movies)):
    print ('Total null values in row ', i, ' is ', movies.iloc[i].isnull().sum())
# Out:
# Total null values in row  0  is  0
# Total null values in row  1  is  0
# Total null values in row  2  is  0
# Total null values in row  3  is  0
# Total null values in row  4  is  14
# Total null values in row  5  is  0
# Total null values in row  6  is  0
# Total null values in row  7  is  0
# Total null values in row  8  is  0
# Total null values in row  9  is  0
# Total null values in row  10  is  0
# Total null values in row  11  is  0
# Total null values in row  12  is  0
# Total null values in row  13  is  0
# Total null values in row  14  is  0
# Total null values in row  15  is  0
# Total null values in row  16  is  0
# Total null values in row  17  is  0
# Total null values in row  18  is  0
# Total null values in row  19  is  0
# Total null values in row  20  is  0
# Total null values in row  21  is  0
# Total null values in row  22  is  0
# Total null values in row  23  is  0
# Total null values in row  24  is  0
# Total null values in row  25  is  0
# ...

# %%
# % of null values column wise
(movies.isnull().sum()/len(movies))*100
# Out:
# color                         0.376760
# director_name                 2.062265
# num_critic_for_reviews        0.991473
# duration                      0.297442
# director_facebook_likes       2.062265
# actor_3_facebook_likes        0.456078
# actor_2_name                  0.257783
# actor_1_facebook_likes        0.138806
# gross                        17.529248
# genres                        0.000000
# actor_1_name                  0.138806
# movie_title                   0.000000
# num_voted_users               0.000000
# cast_total_facebook_likes     0.000000
# actor_3_name                  0.456078
# facenumber_in_poster          0.257783
# plot_keywords                 3.033908
# movie_imdb_link               0.000000
# num_user_for_reviews          0.416419
# language                      0.277613
# country                       0.099147
# content_rating                6.008328
# budget                        9.756098
# title_year                    2.141582
# ...

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 
movies_1 = movies.drop(['color',
'director_facebook_likes',
'actor_1_facebook_likes',
'actor_2_facebook_likes',
'actor_3_facebook_likes',
'actor_2_name',
'cast_total_facebook_likes',
'actor_3_name',
'duration',
'facenumber_in_poster',
'content_rating',
'country',
'movie_imdb_link',
'aspect_ratio',
'plot_keywords'], axis=1)

print ('movies_1 has ', len(movies_1.columns), ' columns.')
movies_1
# Out:
# movies_1 has  13  columns.
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# code for dropping the rows
null_column = []
for column in movies_1.columns:
       if ((movies_1[column].isnull().sum()*100/len(movies_1))) > 5:
           null_column.append(column)

movies_2 = movies_1.dropna(axis = 0, subset = (null_column))
movies_2
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# -  ### Subtask 2.4: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# code for filling the NaN values in the 'language' column 
movies_2["language"].fillna("English") 
movies_2
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# -  ### Subtask 2.5: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# code for checking number of retained rows 
print ('retained rows: ',len(movies_2))
print ('number of rows earlier: ',len(movies))
print ('% of retained rows: ', round(len(movies_2)*100/len(movies),2), '%')
# Out:
# retained rows:  3891
# number of rows earlier:  5043
# % of retained rows:  77.16 %

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# code for unit conversion
def converter(x):
    return x/100000

movies_2['budget'] = converter(movies_2['budget'])
movies_2['gross'] = converter(movies_2['gross'])
movies_3 = movies_2

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Plot `profit` (y-axis) vs `budget` (x- axis) and observe the outliers using the appropriate chart type.
#     4. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# code for creating the profit column
movies_3['profit'] = movies_3['gross'] - movies_3['budget']
movies_3
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  7605.05847
# 1        Gore Verbinski                   302.0  3094.04152
# 2            Sam Mendes                   602.0  2000.74175
# 3     Christopher Nolan                   813.0  4481.30642
# 5        Andrew Stanton                   462.0   730.58679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0     4.24760
# 5034   Neill Dela Llana                    35.0     0.70071
# 5035   Robert Rodriguez                    56.0    20.40920
# 5037       Edward Burns                    14.0     0.04584
# 5042           Jon Gunn                    43.0     0.85222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
#  code for sorting the dataframe
movies_3.sort_values(by = ['profit'], ascending = False)
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  7605.05847
# 29     Colin Trevorrow                   644.0  6521.77271
# 26       James Cameron                   315.0  6586.72302
# 3024      George Lucas                   282.0  4609.35665
# 3080  Steven Spielberg                   215.0  4349.49459
# ...                ...                     ...         ...
# 2334   Katsuhiro Ôtomo                   105.0     4.10388
# 2323    Hayao Miyazaki                   174.0    22.98191
# 3005      Lajos Koltai                    73.0     1.95888
# 3859    Chan-wook Park                   202.0     2.11667
# 2988      Joon-ho Bong                   363.0    22.01412
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
# code for profit vs budget plot 
movies_3.plot(x = 'profit', y = 'budget', style = 'o')
# Out:
# <Axes: xlabel='profit'>

# %%
top10 = movies_3.nlargest(10, 'profit')
top10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  7605.05847
# 29      Colin Trevorrow                   644.0  6521.77271
# 26        James Cameron                   315.0  6586.72302
# 3024       George Lucas                   282.0  4609.35665
# 3080   Steven Spielberg                   215.0  4349.49459
# 17          Joss Whedon                   703.0  6232.79547
# 794         Joss Whedon                   703.0  6232.79547
# 509        Roger Allers                   186.0  4227.83777
# 240        George Lucas                   320.0  4745.44677
# 66    Christopher Nolan                   645.0  5333.16061
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have noticed a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`. Note that the same `movie_title` can be there in different languages.

# %%
# code for dropping duplicate values
movies_4 = movies_2
movies_4['language'].fillna('English')
movies_4.drop_duplicates(subset = 'movie_title', keep = False, inplace = True)
movies_4
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  7605.05847
# 1        Gore Verbinski                   302.0  3094.04152
# 2            Sam Mendes                   602.0  2000.74175
# 3     Christopher Nolan                   813.0  4481.30642
# 5        Andrew Stanton                   462.0   730.58679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0     4.24760
# 5034   Neill Dela Llana                    35.0     0.70071
# 5035   Robert Rodriguez                    56.0    20.40920
# 5037       Edward Burns                    14.0     0.04584
# 5042           Jon Gunn                    43.0     0.85222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
# code for repeating subtask 2
top10_2 = movies_4.sort_values('profit', ascending=False).head(10)
top10_2
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  7605.05847
# 29      Colin Trevorrow                   644.0  6521.77271
# 26        James Cameron                   315.0  6586.72302
# 3024       George Lucas                   282.0  4609.35665
# 3080   Steven Spielberg                   215.0  4349.49459
# 509        Roger Allers                   186.0  4227.83777
# 240        George Lucas                   320.0  4745.44677
# 66    Christopher Nolan                   645.0  5333.16061
# 439           Gary Ross                   673.0  4079.99255
# 812          Tim Miller                   579.0  3630.24263
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'
IMDb_Top_250 = movies_4.nlargest(250, 'imdb_score')
IMDb_Top_250['num_voted_users'] = IMDb_Top_250['num_voted_users'].where(IMDb_Top_250['num_voted_users'] > 25000)
IMDb_Top_250['rank'] = IMDb_Top_250['imdb_score'].rank(method='min', ascending = False)
IMDb_Top_250
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   283.41469
# 3466  Francis Ford Coppola                   208.0  1348.21952
# 66       Christopher Nolan                   645.0  5333.16061
# 2837  Francis Ford Coppola                   149.0   573.00000
# 339          Peter Jackson                   328.0  3770.19252
# ...                    ...                     ...         ...
# 3264        Michael Haneke                   447.0     2.25377
# 3357            Dan Gilroy                   534.0   322.79955
# 3361       Jonathan Dayton                   270.0   598.89948
# 3510           Yash Chopra                    29.0    29.21738
# 3595      Darren Aronofsky                   391.0   262.36603
#
#                               genres      actor_1_name  \
# 1937                     Crime|Drama    Morgan Freeman
# 3466                     Crime|Drama         Al Pacino
# ...

# %%
Top_Foreign_Lang_Film = IMDb_Top_250[IMDb_Top_250['language'] != 'English']
Top_Foreign_Lang_Film
# Out:
#                          director_name  num_critic_for_reviews       gross  \
# 4498                      Sergio Leone                   181.0    61.00000
# 4029                Fernando Meirelles                   214.0    75.63397
# 4747                    Akira Kurosawa                   153.0     2.69061
# 2373                    Hayao Miyazaki                   246.0   100.49886
# 3931                        Ron Fricke                   115.0    26.01847
# 4259  Florian Henckel von Donnersmarck                   215.0   112.84657
# 4921                      Majid Majidi                    46.0     9.25402
# 1298                Jean-Pierre Jeunet                   242.0   332.01661
# 1329                    S.S. Rajamouli                    44.0    64.98000
# 2323                    Hayao Miyazaki                   174.0    22.98191
# 2970                 Wolfgang Petersen                    96.0   114.33134
# ...

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.  Incase of a tie in IMDb score between two directors, sort them alphabetically.

# %%
# code for extracting the top 10 directors
num_column = []
for i in movies_4.columns:
    if (movies_4[i].dtype in ['int64', 'float64']):
        num_column.append(i)

groupedset = movies_4.groupby('director_name')[num_column].mean()
groupedset

top10director = groupedset.sort_values(by = ['imdb_score','director_name'], ascending = [False, True]).head(10)
top10director
# Out:
#                                   num_critic_for_reviews        gross  \
# director_name
# Charles Chaplin                                   120.00     1.632450
# Tony Kaye                                         162.00    67.122410
# Alfred Hitchcock                                  290.00   320.000000
# Damien Chazelle                                   535.00   130.920000
# Florian Henckel von Donnersmarck                  215.00   112.846570
# Majid Majidi                                       46.00     9.254020
# Ron Fricke                                        115.00    26.018470
# Sergio Leone                                      138.00    49.666667
# Christopher Nolan                                 511.25  2266.534470
# Asghar Farhadi                                    354.00    70.984920
#
#                                   num_voted_users  num_user_for_reviews  \
# director_name
# Charles Chaplin                      1.430860e+05            211.000000
# ...

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
delimitedsets = movies_4
delimitedsets[['genres_1','genres_2','genres3','genres4','genres5','genres6','genres7','genres8']] = delimitedsets['genres'].str.split('|',expand=True)
delimitedsets["genres_2"].fillna(delimitedsets["genres_1"]) 
delimitedsets
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  7605.05847
# 1        Gore Verbinski                   302.0  3094.04152
# 2            Sam Mendes                   602.0  2000.74175
# 3     Christopher Nolan                   813.0  4481.30642
# 5        Andrew Stanton                   462.0   730.58679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0     4.24760
# 5034   Neill Dela Llana                    35.0     0.70071
# 5035   Robert Rodriguez                    56.0    20.40920
# 5037       Edward Burns                    14.0     0.04584
# 5042           Jon Gunn                    43.0     0.85222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
num_column = []
for column in delimitedsets:
    if (delimitedsets[column].dtype in ['int64', 'float64']):
        num_column.append(column)
movies_by_segment = delimitedsets.groupby(['genres_1','genres_2'])[num_column].mean()
movies_by_segment
# Out:
#                     num_critic_for_reviews        gross  num_voted_users  \
# genres_1 genres_2
# Action   Adventure              215.543307  1056.448079    175651.440945
#          Animation              184.625000   926.805149     78015.375000
#          Biography              165.857143   443.554224     86330.928571
#          Comedy                 136.370079   523.078605     80718.448819
#          Crime                  162.515152   410.842587     98257.569697
# ...                                    ...          ...              ...
# Mystery  Romance                 67.000000   159.575330     12596.500000
#          Sci-Fi                 290.800000   446.251542    188579.800000
#          Thriller               229.642857   552.767794    214124.000000
# Romance  Sci-Fi                 413.000000   624.533150    200035.000000
# Sci-Fi   Thriller               200.000000   297.937900    169014.428571
#
#                     num_user_for_reviews       budget   title_year  \
# ...

# %%
PopGenre = movies_by_segment.nlargest(5, 'gross')
PopGenre
# Out:
#                      num_critic_for_reviews        gross  num_voted_users  \
# genres_1  genres_2
# Family    Sci-Fi                 215.000000  4349.494590    281842.000000
# Adventure Sci-Fi                 344.375000  2286.277585    290322.500000
#           Animation              170.061404  1154.105200    137771.675439
# Action    Adventure              215.543307  1056.448079    175651.440945
# Adventure Fantasy                284.555556  1024.069849    197128.222222
#
#                      num_user_for_reviews       budget   title_year  \
# genres_1  genres_2
# Family    Sci-Fi               515.000000   105.000000  1982.000000
# Adventure Sci-Fi               915.500000  1045.000000  2007.750000
#           Animation            241.894737  1061.026316  2006.263158
# Action    Adventure            556.383202   963.937364  2001.755906
# Adventure Fantasy              473.777778  1034.444444  2004.222222
#
#                      imdb_score  movie_facebook_likes       profit
# ...

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_users_for_review` and identify the actors which have the highest mean.
#     5. Observe the change in number of voted users over decades using a bar chart. Create a column called `decade` which represents the decade to which every movie belongs to. For example, the  `title_year`  year 1923, 1925 should be stored as 1920s. Sort the dataframe based on the column `decade`, group it by `decade` and find the sum of users voted in each decade. Store this in a new data frame called `df_by_decade`.

# %%
Meryl_Streep = movies_4[movies_4['actor_1_name'] == 'Meryl Streep']
Meryl_Streep
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 410     Nancy Meyers                   187.0  1127.03470
# 1106   Curtis Hanson                    42.0   468.15748
# 1204     Nora Ephron                   252.0   941.25426
# 1408   David Frankel                   208.0  1247.32962
# 1483  Robert Redford                   227.0   149.98070
# 1575  Sydney Pollack                    66.0   871.00000
# 1618   David Frankel                   234.0   635.36011
# 1674   Carl Franklin                    64.0   232.09440
# 1925  Stephen Daldry                   174.0   415.97830
# 2781  Phyllida Lloyd                   331.0   299.59436
# 3135   Robert Altman                   211.0   203.38609
#
#                                genres  actor_1_name  \
# 410              Comedy|Drama|Romance  Meryl Streep
# 1106  Action|Adventure|Crime|Thriller  Meryl Streep
# 1204          Biography|Drama|Romance  Meryl Streep
# 1408             Comedy|Drama|Romance  Meryl Streep
# ...

# %%
Leo_Caprio = movies_4[movies_4['actor_1_name'] == 'Leonardo DiCaprio']
Leo_Caprio
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 26            James Cameron                   315.0  6586.72302
# 97        Christopher Nolan                   642.0  2925.68851
# 179   Alejandro G. Iñárritu                   556.0  1836.35922
# 257         Martin Scorsese                   267.0  1026.08827
# 296       Quentin Tarantino                   765.0  1628.04648
# 307            Edward Zwick                   166.0   573.66262
# 308         Martin Scorsese                   606.0  1168.66727
# 326         Martin Scorsese                   233.0   776.79638
# 361         Martin Scorsese                   352.0  1323.73442
# 452         Martin Scorsese                   490.0  1279.68405
# 641            Ridley Scott                   238.0   393.80442
# 911        Steven Spielberg                   194.0  1644.35221
# 990             Danny Boyle                   118.0   397.78599
# 1114             Sam Mendes                   323.0   228.77808
# ...

# %%
Brad_Pitt = movies_4[movies_4['actor_1_name'] == 'Brad Pitt']
Brad_Pitt
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 101           David Fincher                   362.0  1274.90802
# 147       Wolfgang Petersen                   220.0  1332.28348
# 254       Steven Soderbergh                   198.0  1255.31634
# 255              Doug Liman                   233.0  1863.36103
# 382              Tony Scott                   142.0     0.26871
# 400       Steven Soderbergh                   186.0  1834.05771
# 470              David Ayer                   406.0   857.07116
# 611     Jean-Jacques Annaud                    76.0   379.01509
# 683           David Fincher                   315.0   370.23395
# 792         Patrick Gilmore                    98.0   262.88320
# 940             Neil Jordan                   120.0  1052.64608
# 1490        Terrence Malick                   584.0   133.03319
# 1722         Andrew Dominik                   273.0    39.04982
# 2204  Alejandro G. Iñárritu                   285.0   343.00771
# ...

# %%
# Write your code for combining the three dataframes here
combined = pd.concat([Meryl_Streep, Leo_Caprio, Brad_Pitt])
combined
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 410            Nancy Meyers                   187.0  1127.03470
# 1106          Curtis Hanson                    42.0   468.15748
# 1204            Nora Ephron                   252.0   941.25426
# 1408          David Frankel                   208.0  1247.32962
# 1483         Robert Redford                   227.0   149.98070
# 1575         Sydney Pollack                    66.0   871.00000
# 1618          David Frankel                   234.0   635.36011
# 1674          Carl Franklin                    64.0   232.09440
# 1925         Stephen Daldry                   174.0   415.97830
# 2781         Phyllida Lloyd                   331.0   299.59436
# 3135          Robert Altman                   211.0   203.38609
# 26            James Cameron                   315.0  6586.72302
# 97        Christopher Nolan                   642.0  2925.68851
# 179   Alejandro G. Iñárritu                   556.0  1836.35922
# ...

# %%
# code for grouping the combined dataframe
num_column = []
for i in combined.columns:
    if(combined[i].dtype in ['int64', 'float64']):
        num_column.append(i)

combined_grp = combined.groupby(['actor_1_name'])[num_column].mean()
combined_grp
# Out:
#                    num_critic_for_reviews        gross  num_voted_users  \
# actor_1_name
# Brad Pitt                      245.000000   663.214487    283583.823529
# Leonardo DiCaprio              313.368421  1237.345359    450278.473684
# Meryl Streep                   181.454545   599.197275     73545.545455
#
#                    num_user_for_reviews      budget   title_year  imdb_score  \
# actor_1_name
# Brad Pitt                    742.352941  692.941176  2004.352941    7.152941
# Leonardo DiCaprio            931.473684  800.789474  2004.684211    7.515789
# Meryl Streep                 297.181818  344.545455  2003.545455    6.745455
#
#                    movie_facebook_likes      profit
# actor_1_name
# Brad Pitt                  14051.764706  -29.726689
# Leonardo DiCaprio          45578.947368  436.555885
# Meryl Streep                2934.090909  254.651820

# %%
# code for finding the mean of critic reviews and audience reviews
combined_grp = combined.groupby(['actor_1_name'])[num_column].mean()
mn_critic_rvw =combined_grp.sort_values('num_critic_for_reviews', ascending=False).head(1)
mn_usr_rvw =combined_grp.sort_values('num_user_for_reviews', ascending=False).head(1)
mn_critic_rvw
mn_usr_rvw
# Out:
#                    num_critic_for_reviews        gross  num_voted_users  \
# actor_1_name
# Leonardo DiCaprio              313.368421  1237.345359    450278.473684
#
#                    num_user_for_reviews      budget   title_year  imdb_score  \
# actor_1_name
# Leonardo DiCaprio            931.473684  800.789474  2004.684211    7.515789
#
#                    movie_facebook_likes      profit
# actor_1_name
# Leonardo DiCaprio          45578.947368  436.555885

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!

# %%
# code for calculating decade
movies_5 = movies_4
movies_5['Decade'] = (movies_5['title_year']//10*10)
movies_5['Decade'] = movies_5['Decade'].astype(str)
movies_5
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  7605.05847
# 1        Gore Verbinski                   302.0  3094.04152
# 2            Sam Mendes                   602.0  2000.74175
# 3     Christopher Nolan                   813.0  4481.30642
# 5        Andrew Stanton                   462.0   730.58679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0     4.24760
# 5034   Neill Dela Llana                    35.0     0.70071
# 5035   Robert Rodriguez                    56.0    20.40920
# 5037       Edward Burns                    14.0     0.04584
# 5042           Jon Gunn                    43.0     0.85222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
# code for creating the data frame df_by_decade
df_by_decade = movies_5.groupby(['Decade'])[num_column].sum()

df_by_decade
# Out:
#         num_critic_for_reviews         gross  num_voted_users  \
# Decade
# 1920.0                   297.0      58.34435           116392
# 1930.0                   766.0    4112.46620           804839
# 1940.0                   464.0    2077.13927           230838
# 1950.0                   764.0    1470.69061           678336
# 1960.0                  3094.0   10503.96801          2983442
# 1970.0                  5344.0   33260.41414          8015561
# 1980.0                 18483.0  103315.03185         18596981
# 1990.0                 60205.0  341691.19186         69182961
# 2000.0                252307.0  767468.91175        159582998
# 2010.0                242181.0  560051.87672        110078938
#
#         num_user_for_reviews        budget  title_year  imdb_score  \
# Decade
# 1920.0                 485.0      64.79000      5776.0        19.4
# 1930.0                1849.0     113.25000     11619.0        48.1
# ...

# %%
#code for plotting number of voted users vs decade
barplot = df_by_decade.plot.bar( y='num_voted_users', rot=0)
